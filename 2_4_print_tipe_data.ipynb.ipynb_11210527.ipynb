# %%
print(True)
print("Mari Belajar Python")
print('Belajar Python dengan sangat mudah')
print(20)
print(3.14)
print(1,2,3,4,5)
print(["satu","dua","tiga"])
print((1,2,3,4,5))
print(("satu","dua","tiga"))
print({"nama":"Said", 'umur':24})
# Out:
# True
# Mari Belajar Python
# Belajar Python dengan sangat mudah
# 20
# 3.14
# 1 2 3 4 5
# ['satu', 'dua', 'tiga']
# (1, 2, 3, 4, 5)
# ('satu', 'dua', 'tiga')
# {'nama': 'Said', 'umur': 24}

# %%
var_string="Mari Belajar Python"
var_int=10
var_float=3.14
var_list=[1,2,3,4,5]
var_tuple=("satu","dua","tiga")
var_dict={"nama":"Said",'umur':24}


print(var_string)
print(var_int)
print(var_float)
print(var_list)
print(var_tuple)
print(var_dict)
# Out:
# Mari Belajar Python
# 10
# 3.14
# [1, 2, 3, 4, 5]
# ('satu', 'dua', 'tiga')
# {'nama': 'Said', 'umur': 24}

# %%
var_string="Mari Belajar Python"
var_int=10
var_float=3.14
var_list=[1,2,3,4,5]
var_tuple=("satu","dua","tiga")
var_dict={"nama":"Said",'umur':24}


print(var_string)
print(var_int)
print(var_float)
print(var_list)
print(var_tuple)
print(var_dict)

print(type(var_string))
print(type(var_int))
print(type(var_float))
print(type(var_list))
print(type(var_tuple))
print(type(var_dict))
# Out:
# Mari Belajar Python
# 10
# 3.14
# [1, 2, 3, 4, 5]
# ('satu', 'dua', 'tiga')
# {'nama': 'Said', 'umur': 24}
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>
